# %%
import numpy as np
import h5py

print(np.sin(50))
print('hello mik')
# Out:
# -0.26237485370392877
# hello mik

# %%
import matplotlib.pyplot as plt

data = np.random.rand(1000)
plt.hist(data, bins=30, alpha=0.5, color='blue')
plt.show()
